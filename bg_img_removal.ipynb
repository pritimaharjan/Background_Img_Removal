# %%
from rembg import remove
from PIL import Image
input_path="img1_initial.jpg"
output_path="output.png"
input_image=Image.open(input_path)
output_image=remove(input_image)
output_image.save(output_path)

# %%
input_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=448x291>

# %%
output_image
# Out:
# <PIL.Image.Image image mode=RGBA size=448x291>
